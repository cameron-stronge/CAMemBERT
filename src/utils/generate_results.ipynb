# %%
cd drive/MyDrive/CAMemBERT-Adapters/
# Out:
# /content/drive/MyDrive/CAMemBERT-Adapters

# %%
# import os, sys
# currentdir = os.path.dirname(os.path.realpath(__file__))
# preprocess_mod_ind = currentdir.split('/').index('CAMemBERT-Adapters')
# preprocess_mod_path = '/'.join(currentdir.split('/')[:preprocess_mod_ind+1])
# sys.path.append(preprocess_mod_path)
import glob
import json
import pandas as pd
for file_path in glob.glob('results/tasks/**/subtasks/**/evaluation_file.json'):
    subtask_fp = '/'.join(file_path.split('/')[:-1])
    # Opening JSON file
    f = open(file_path,)
    data = json.load(f)
    f.close()
    eval_df = pd.DataFrame(data)
    print(eval_df)
    eval_df.to_csv(subtask_fp + '/evaluation_file.csv')
# Out:
#    eval_loss   eval_f1  eval_accuracy  ...  task    subtask                 time
# 0   0.455149  0.847545       0.776091  ...   ged  seq_class  25/06/2021 14:37:11
# 1   0.441702  0.882667       0.833017  ...   ged  seq_class  25/06/2021 14:40:07
# 2   1.202945  0.835391       0.796438  ...   ged  seq_class  25/06/2021 14:45:04
# 3   0.466545  0.817121       0.760814  ...   ged  seq_class  25/06/2021 15:01:53
#
# [4 rows x 17 columns]
#    eval_loss   eval_f1  eval_accuracy  ...  task    subtask                 time
# 0   0.253980  0.245632       0.897856  ...   ged  seq_2_seq  25/06/2021 13:20:49
# 1   0.296513  0.208351       0.918327  ...   ged  seq_2_seq  25/06/2021 13:34:53
#
# [2 rows x 17 columns]
#    eval_loss  eval_spearmanr  ...     subtask                 time
# 0   0.026611        0.958299  ...  regression  25/06/2021 13:02:55
# 1   0.032784        0.939967  ...  regression  25/06/2021 13:42:57
# 2   0.009727        0.763655  ...  regression  25/06/2021 13:53:52
# 3   0.012238        0.674052  ...  regression  25/06/2021 14:00:40
# 4   0.031999        0.938749  ...  regression  25/06/2021 14:15:28
#
# [5 rows x 18 columns]
